# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="21exSaESwqFL0ur2m4cQ")
project = rf.workspace("mehdi-cko8a").project("lemon_kumquat_robust-jf4n3")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 57.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Lemon_Kumquat_Robust-1 in yolov5pytorch:: 100%|██████████| 690/690 [00:00<00:00, 1426.10it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17410, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 17410 (delta 63), reused 22 (delta 22), pack-reused 17326 (from 3)
# Receiving objects: 100% (17410/17410), 16.29 MiB | 25.75 MiB/s, done.
# Resolving deltas: 100% (11928/11928), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...

# %%
# Prédire une image directement avec le modèle RoboFlow hébergé
prediction = version.model.predict("/content/Lemon_Kumquat_Robust-1/test/images/frame_0003_jpg.rf.2a2ca9d331a800cb3135a1610e5c84c3.jpg", confidence=40, overlap=30)
prediction.save("prediction.jpg")  # Sauvegarde l’image avec les bounding boxes
prediction.plot()                  # Affiche l’image avec les prédictions dans le notebook

# %%
# Prédire une image
prediction = version.model.predict(
    "/content/Lemon_Kumquat_Robust-1/test/images/frame_0003_jpg.rf.2a2ca9d331a800cb3135a1610e5c84c3.jpg",
    confidence=40,
    overlap=30
)

# Sauvegarde et affichage de l’image prédite
prediction.save("prediction.jpg")
prediction.plot()

# Compter le nombre de fruits détectés
nombre_fruits = len(prediction.json()['predictions'])
print(f"Nombre de fruits détectés : {nombre_fruits}")
# Out:
# Nombre de fruits détectés : 13
